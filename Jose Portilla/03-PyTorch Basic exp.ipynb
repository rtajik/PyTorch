# %%
import torch
import numpy as np

# %%
torch.__version__
# Out:
# '1.12.1'

# %%
arr = np.array([1,2,3])
arr
# Out:
# array([1, 2, 3])

# %%
print(type(arr), arr.dtype)
# Out:
# <class 'numpy.ndarray'> int32

# %%
x1 = torch.from_numpy(arr)
print(type(x1), x1.dtype)
# Out:
# <class 'torch.Tensor'> torch.int32

# %%
x2 = torch.as_tensor(arr)
print(type(x2), x2.dtype)
# Out:
# <class 'torch.Tensor'> torch.int32

# %%
x3 = torch.tensor(arr)
print(type(x3), x3.dtype)
# Out:
# <class 'torch.Tensor'> torch.int32

# %%
x4 = torch.Tensor(arr)
print(type(x4), x4.dtype)
# Out:
# <class 'torch.Tensor'> torch.float32

# %%
arr[0]=100
print(arr)
print(x1)
print(x2)
print(x3)
print(x4)
# Out:
# [100   2   3]
# tensor([100,   2,   3], dtype=torch.int32)
# tensor([100,   2,   3], dtype=torch.int32)
# tensor([1, 2, 3], dtype=torch.int32)
# tensor([1., 2., 3.])

# %%
a = torch.empty(4,2)

# %%
b = torch.zeros(4,3)
b.dtype
# Out:
# torch.float32

# %%
b2 = torch.zeros(4,3, dtype=torch.int32)
b2.dtype
# Out:
# torch.int32

# %%
c = torch.ones(4,2)
c
# Out:
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.],
#         [1., 1.]])

# %%
d = torch.tensor([1, 2, 3])
d
# Out:
# tensor([1, 2, 3])

# %%
f = torch.Tensor([1, 2, 3])
f
# Out:
# tensor([1., 2., 3.])

# %%
x = torch.arange(0,6).reshape(3,2)
x
# Out:
# tensor([[0, 1],
#         [2, 3],
#         [4, 5]])

# %%
y = x[:,1]
y.shape
# Out:
# torch.Size([3])

# %%
y = x[:,:-1]
y.shape
# Out:
# torch.Size([3, 1])

# %%
x = torch.arange(0,6)

# %%
yv = x.view(2,3)

# %%
yr= x.reshape(2,3)

# %%
yc = x.clone().reshape(2, 3)

# %%
x[0] = 100
print(x, yv, yr, yc, sep='\n')
# Out:
# tensor([100,   1,   2,   3,   4,   5])
# tensor([[100,   1,   2],
#         [  3,   4,   5]])
# tensor([[100,   1,   2],
#         [  3,   4,   5]])
# tensor([[0, 1, 2],
#         [3, 4, 5]])

# %%
# y = torch.copy_(x)

# %%
yr.add_(yc)
print(yr, yc, sep='\n')
# Out:
# tensor([[100,   2,   4],
#         [  6,   8,  10]])
# tensor([[0, 1, 2],
#         [3, 4, 5]])

# %%
yr.mul(yc)
# Out:
# tensor([[ 0,  2,  8],
#         [18, 32, 50]])

# %%
# yr.mul(yc.T)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13032\1235225188.py in <module>
# ----> 1 yr.mul(yc.T)
#
# RuntimeError: The size of tensor a (3) must match the size of tensor b (2) at non-singleton dimension 1

# %%
x = torch.arange(0,6)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13032\854556197.py in <module>
#       1 x = torch.arange(0,6)
# ----> 2 x.dot(x.mT)
#
# RuntimeError: tensor.mT is only supported on matrices or batches of matrices. Got 1-D tensor.

# %%
x
# Out:
# tensor([0, 1, 2, 3, 4, 5])

# %%
x.matmul(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13032\3787827745.py in <module>
# ----> 1 x.matmul_(x)
#
# AttributeError: 'Tensor' object has no attribute 'matmul_'

# %%
yr.mm(yc.T)
print(yr, yc, sep='\n')
# Out:
# tensor([[ 10, 328],
#         [ 28, 100]])

# %%
yr@yc.T
print(yr, yc, sep='\n')
# Out:
# tensor([[100,   2,   4],
#         [  6,   8,  10]])
# tensor([[0, 1, 2],
#         [3, 4, 5]])

# %%
torch.manual_seed(42)
X3D = torch.rand(2,2,2)
X3D
# Out:
# tensor([[[0.8823, 0.9150],
#          [0.3829, 0.9593]],
#
#         [[0.3904, 0.6009],
#          [0.2566, 0.7936]]])

# %%
torch.manual_seed(101)
Y3D = torch.rand(2,2,2)
Y3D
# Out:
# tensor([[[0.1980, 0.4503],
#          [0.0909, 0.8872]],
#
#         [[0.2894, 0.0186],
#          [0.9095, 0.3406]]])

# %%
Z3D = X3D.matmul(Y3D)
Z3D
# Out:
# tensor([[[0.2579, 1.2091],
#          [0.1630, 1.0235]],
#
#         [[0.6595, 0.2119],
#          [0.7961, 0.2751]]])

# %%
Z3D = X3D@Y3D
Z3D
# Out:
# tensor([[[0.2579, 1.2091],
#          [0.1630, 1.0235]],
#
#         [[0.6595, 0.2119],
#          [0.7961, 0.2751]]])

# %%
X3D.norm(keepdim=True)
# Out:
# tensor([[[1.9727]]])

# %%
X3D.numel()
# Out:
# 8

# %%
x = torch.rand(1, 4, 3, 1)
x
# Out:
# tensor([[[[0.1578],
#           [0.7040],
#           [0.0616]],
#
#          [[0.3781],
#           [0.5510],
#           [0.7550]],
#
#          [[0.8346],
#           [0.0104],
#           [0.2535]],
#
#          [[0.4538],
#           [0.5163],
#           [0.6199]]]])

# %%
len(x)
# Out:
# 1

# %%
x.ndim
# Out:
# 4
