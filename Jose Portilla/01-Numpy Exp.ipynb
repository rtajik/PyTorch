# %%
import numpy as np

# %%
mylist = [1, 2, 3, 4]

# %%
type(mylist)
# Out:
# list

# %%
arr_vec = np.array(mylist)
arr_mat = arr_vec.reshape(-1, 1)

# %%
print(type(arr_vec), type(arr_mat))
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
print('Vector Shape:', arr_vec.shape, 'Matrix Shape:', arr_mat.shape)
# Out:
# Vector Shape: (4,) Matrix Shape: (4, 1)

# %%
print('Vector dim:', arr_vec.ndim, 'Matrix dim:', arr_mat.ndim)
# Out:
# Vector dim: 1 Matrix dim: 2

# %%
arr1 = np.arange(20,10,-.5)
arr1
# Out:
# array([20. , 19.5, 19. , 18.5, 18. , 17.5, 17. , 16.5, 16. , 15.5, 15. ,
#        14.5, 14. , 13.5, 13. , 12.5, 12. , 11.5, 11. , 10.5])

# %%
arr1.ndim
# Out:
# 1

# %%
zeros_arr_vec = np.zeros(5)
zeros_arr_mat = np.zeros((5,1))
print('Zero Vector Shape:', zeros_arr_vec.shape, 'Zeros Matrix Shape:', zeros_arr_mat.shape)
# Out:
# Zero Vector Shape: (5,) Zeros Matrix Shape: (5, 1)

# %%
# arr0 = np.arange(0,4).reshape(-1,1)
arr0 = np.arange(0,4)
# print(arr0.shape)
aa = arr_vec + arr0
print('arr0',arr0.shape,'aa', aa.shape)
# Out:
# arr0 (4,) aa (4,)

# %%
arr1 = np.arange(0,4).reshape(1,-1)
aa = arr_vec + arr1
print('arr1',arr1.shape,'aa', aa.shape)
# Out:
# arr1 (1, 4) aa (1, 4)

# %%
arr1 = np.arange(0,4).reshape(-1,1)
print(arr1.shape)
aa = arr_vec + arr1
print('arr1',arr1.shape,'aa', aa.shape)
print(aa)
# Out:
# (4, 1)
# arr1 (4, 1) aa (4, 4)
# [[1 2 3 4]
#  [2 3 4 5]
#  [3 4 5 6]
#  [4 5 6 7]]

# %%
arr_vec2 = np.array([2,3,4,5, 6])
arr_mat2 = arr_vec2.reshape(-1, 1)
aa = arr_vec + arr_mat2
print('arr_mat2', arr_mat2.shape,'arr_vec', arr_vec.shape,'aa', aa.shape)
print(aa)
# Out:
# arr_mat2 (5, 1) arr_vec (4,) aa (5, 4)
# [[ 3  4  5  6]
#  [ 4  5  6  7]
#  [ 5  6  7  8]
#  [ 6  7  8  9]
#  [ 7  8  9 10]]

# %%
arr_vec2 = np.array([1,2,3,4,5,6,7,8])
arr_mat2 = arr_vec2.reshape(2, 4)
aa = arr_vec + arr_mat2
print('arr_mat2', arr_mat2.shape,'arr_vec', arr_vec.shape,'aa', aa.shape)
print('arr_mat2', arr_mat2,'arr_vec', arr_vec,'aa', aa, sep = '\n')
# Out:
# arr_mat2 (2, 4) arr_vec (4,) aa (2, 4)
# arr_mat2
# [[1 2 3 4]
#  [5 6 7 8]]
# arr_vec
# [1 2 3 4]
# aa
# [[ 2  4  6  8]
#  [ 6  8 10 12]]

# %%
# arr_vec2 = np.array([1,2,3,4,5,6,7,8])
# arr_mat2 = arr_vec2.reshape(4,2)
# aa = arr_vec + arr_mat2
# print('arr_mat2', arr_mat2.shape,'arr_vec', arr_vec.shape,'aa', aa.shape)
# print('arr_mat2', arr_mat2,'arr_vec', arr_vec,'aa', aa, sep = '\n')

# %%
# arr_vec2 = np.array([1,2,3,4,5,6,7,8])
# arr_mat2 = arr_vec2.reshape(1,-1)
# print('arr_mat2', arr_mat2.shape)
# print('arr_vec', arr_vec.shape)
# aa = arr_vec + arr_mat2

# print('arr_mat2', arr_mat2,'arr_vec', arr_vec,'aa', aa, sep = '\n')

# %%
arr_vec2 = np.array([1,2,3,4])
arr_mat2 = arr_vec2.reshape(4,1)
arr_mat3 = arr_vec2.reshape(1,4)
print('arr_mat2', arr_mat2.shape)
print('arr_mat3', arr_mat3.shape)

aa = arr_mat3 + arr_mat2

print('aa', aa.shape)
print('aa', aa)
# Out:
# arr_mat2 (4, 1)
# arr_mat3 (1, 4)
# aa (4, 4)
# aa [[2 3 4 5]
#  [3 4 5 6]
#  [4 5 6 7]
#  [5 6 7 8]]

# %%
arr_vec2 = np.array([1,2,3,4])
arr_vec3 = np.array([1,2,3,4,5])

arr_mat2 = arr_vec2.reshape(1,4)
arr_mat3 = arr_vec3.reshape(5,1)
print('arr_mat2', arr_mat2.shape)
print('arr_mat3', arr_mat3.shape)

aa = arr_mat3 + arr_mat2

print('aa', aa.shape)
print('aa', aa)
# Out:
# arr_mat2 (1, 4)
# arr_mat3 (5, 1)
# aa (5, 4)
# aa [[2 3 4 5]
#  [3 4 5 6]
#  [4 5 6 7]
#  [5 6 7 8]
#  [6 7 8 9]]

# %%
# arr_vec2 = np.array([1,2,3,4])
# arr_vec3 = np.array([1,2,3,4,5])

# arr_mat2 = arr_vec2.reshape(1,4)
# arr_mat3 = arr_vec3.reshape(1,5)
# print('arr_mat2', arr_mat2.shape)
# print('arr_mat3', arr_mat3.shape)

# aa = arr_mat3 + arr_mat2

# print('aa', aa.shape)
# print('aa', aa)

# %%
# arr_vec2 = np.array([1,2,3,4])
# arr_vec3 = np.array([1,2,3,4,5,6,7,8])

# arr_mat2 = arr_vec2.reshape(1,4)
# arr_mat3 = arr_vec3.reshape(4,2)
# print('arr_mat2', arr_mat2.shape)
# print('arr_mat3', arr_mat3.shape)

# aa = arr_mat3 + arr_mat2

# print('aa', aa.shape)
# print('aa', aa)

# %%
arr_vec2 = np.array([1,2,3,4])
arr_vec3 = np.array([1,2,3,4,5,6,7,8])

arr_mat2 = arr_vec2.reshape(1,4)
arr_mat3 = arr_vec3.reshape(2,4)
print('arr_mat2', arr_mat2.shape)
print('arr_mat3', arr_mat3.shape)

aa = arr_mat3 + arr_mat2

print('aa', aa.shape)
print('aa', aa)
# Out:
# arr_mat2 (1, 4)
# arr_mat3 (2, 4)
# aa (2, 4)
# aa [[ 2  4  6  8]
#  [ 6  8 10 12]]

# %%
arr_vec2 = np.array([1,2])
arr_vec3 = np.array([1,2,3,4,5,6,7,8])

arr_mat2 = arr_vec2.reshape(2,1)
arr_mat3 = arr_vec3.reshape(1,2,4)
print('arr_mat2 shape', arr_mat2.shape)
print('arr_mat2', arr_mat2)

print('arr_mat3 shape', arr_mat3.shape)
print('arr_mat3', arr_mat3)
aa = arr_mat3 + arr_mat2

print('aa', aa.shape)
print('aa', aa)
# Out:
# arr_mat2 shape (2, 1)
# arr_mat2 [[1]
#  [2]]
# arr_mat3 shape (1, 2, 4)
# arr_mat3 [[[1 2 3 4]
#   [5 6 7 8]]]
# aa (1, 2, 4)
# aa [[[ 2  3  4  5]
#   [ 7  8  9 10]]]

# %%
arr = np.linspace(0,10,20)
arr.shape
# Out:
# (20,)

# %%
np.random.rand(4,2).shape
# Out:
# (4, 2)

# %%
np.random.rand(4,1).shape
# Out:
# (4, 1)

# %%
np.random.rand(4).shape
# Out:
# (4,)

# %%
np.random.randn(4,2).shape
# Out:
# (4, 2)

# %%
np.random.normal(5,2,(4,2)).shape
# Out:
# (4, 2)

# %%
a = np.random.normal(5,2,(4,2))

# %%
np.random.randint(1,15,10).shape
# Out:
# (10,)

# %%
np.random.randint(1,5,10)
# Out:
# array([1, 4, 4, 3, 3, 4, 2, 1, 3, 1])

# %%
np.random.seed(421)

# %%
a1 = a.max()
a2 = np.max(a)
print(a1,a2)
# Out:
# 9.962049602660008 9.962049602660008

# %%
a1 = a.max(axis=0)
a2 = np.max(a,axis=0)
print(a1,a2)
# Out:
# [9.9620496  4.30368086] [9.9620496  4.30368086]

# %%
a1 = a.argmax()
a2 = np.argmax(a)
print(a1,a2)
# Out:
# 0 0

# %%
a1 = a.argmax(axis=0)
a2 = np.argmax(a,axis=0).shape
print(a1,a2)
# Out:
# [0 3] (2,)

# %%
arr1 = np.arange(0,5)
arr2 = np.arange(0,5,.5)

# %%
arr3 = arr2[arr2>2.1]
arr3
# Out:
# array([2.5, 3. , 3.5, 4. , 4.5])

# %%
1/(arr1-2)
# Out:
# c:\Users\mm\anaconda3\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# array([-0.5, -1. ,  inf,  1. ,  0.5])
